# %% [markdown]
# # Debiassing Classification Variational Auto Encoder

# %%
from setup import Config
from main import make_trainer, make_evaluator
from logger import logger
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import utils

# Change icons to be notebook compatible
logger.set_notebook_syntax()

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Initialising config & trainer
# Create a config file in which we can pass along the required settings for the training model

# %%
# Make a trainer, train
config = Config(run_folder='train', debias_type='max')
trainer = make_trainer(config)
# Out:
# 2021-04-13 18:02:47,628 - DebiasingModel - INFO -  💿 Saving new run files to train
#
# 2021-04-13 18:02:50,888 - DebiasingModel - INFO - Creating new model with the following parameters:
# z_dim: 200
# hist_size: 1000
# alpha: 0.01
# num_bins: 10
#
#
# 2021-04-13 18:02:50,983 - DebiasingModel - INFO - Creating the celeb and imagenet dataset from the h5 file!
#
# 2021-04-13 18:03:22,519 - DebiasingModel - INFO - Sizes of dataset are:
# Celeb-train: 43965
# Celeb-valid: 10992
# Imagenet-train: 43965
# Imagenet-valid: 10992

# %% [markdown]
# ### Review the architecture of the encoder and decoder
# First we have a look on the architecture of the encodering and decoding networks

# %%
trainer.model
# Out:
# Db_vae(
#   (encoder): Encoder(
#     (layers): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2))
#       (7): LeakyReLU(negative_slope=0.01)
#       (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2))
#       (10): LeakyReLU(negative_slope=0.01)
#       (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): Flatten()
#       (13): Linear(in_features=512, out_features=1000, bias=True)
#       (14): LeakyReLU(negative_slope=0.01)
#       (15): Linear(in_features=1000, out_features=401, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (layers): Sequential(
#       (0): Linear(in_features=200, out_features=1000, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=1000, out_features=512, bias=True)
#       (3): UnFlatten()
#       (4): ConvTranspose2d(512, 256, kernel_size=(5, 5), stride=(2, 2))
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2))
#       (8): LeakyReLU(negative_slope=0.01)
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), output_padding=(1, 1))
#       (11): LeakyReLU(negative_slope=0.01)
#       (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (13): ConvTranspose2d(64, 3, kernel_size=(5, 5), stride=(2, 2), output_padding=(1, 1))
#       (14): Sigmoid()
#     )
#   )
# )

# %% [markdown]
# ### Perform the training for 10 epochs

# %%
trainer.train(10)
# Out:
# 2021-04-13 18:03:22,550 - DebiasingModel - INFO - Starting epoch: 1/10
#
# 2021-04-13 18:03:22,551 - DebiasingModel - INFO - Updating weight histogram using method: max
#
# 2021-04-13 18:03:57,105 - DebiasingModel - INFO -  💿 Saving a bias probability figure in results/train/bias_probs/epoch=0
#
# 2021-04-13 18:05:55,149 - DebiasingModel - INFO - Training: batch:0 accuracy:0.51171875
#
# 2021-04-13 18:05:57,690 - DebiasingModel - INFO - Training: batch:5 accuracy:0.953125
#
# 2021-04-13 18:06:00,129 - DebiasingModel - INFO - Training: batch:10 accuracy:0.984375
#
# 2021-04-13 18:06:02,718 - DebiasingModel - INFO - Training: batch:15 accuracy:0.9921875
#
# 2021-04-13 18:06:05,455 - DebiasingModel - INFO - Training: batch:20 accuracy:0.98828125
#
# 2021-04-13 18:06:08,288 - DebiasingModel - INFO - Training: batch:25 accuracy:0.96875
#
# 2021-04-13 18:06:11,136 - DebiasingModel - INFO - Training: batch:30 accuracy:0.9765625
#
# 2021-04-13 18:06:13,648 - DebiasingModel - INFO - Training: batch:35 accuracy:0.96875
#
# 2021-04-13 18:06:16,078 - DebiasingModel - INFO - Training: batch:40 accuracy:0.9921875
#
# 2021-04-13 18:06:18,546 - DebiasingModel - INFO - Training: batch:45 accuracy:0.98828125
#
# 2021-04-13 18:06:21,032 - DebiasingModel - INFO - Training: batch:50 accuracy:0.98828125
#
# 2021-04-13 18:06:23,469 - DebiasingModel - INFO - Training: batch:55 accuracy:0.9921875
#
# 2021-04-13 18:06:25,885 - DebiasingModel - INFO - Training: batch:60 accuracy:0.98828125
#
# 2021-04-13 18:06:28,302 - DebiasingModel - INFO - Training: batch:65 accuracy:0.98828125
#
# 2021-04-13 18:06:30,765 - DebiasingModel - INFO - Training: batch:70 accuracy:0.98828125
#
# 2021-04-13 18:06:33,184 - DebiasingModel - INFO - Training: batch:75 accuracy:0.99609375
#
# 2021-04-13 18:06:35,715 - DebiasingModel - INFO - Training: batch:80 accuracy:0.9921875
#
# 2021-04-13 18:06:38,241 - DebiasingModel - INFO - Training: batch:85 accuracy:0.98828125
#
# 2021-04-13 18:06:40,641 - DebiasingModel - INFO - Training: batch:90 accuracy:0.9765625
#
# 2021-04-13 18:06:43,040 - DebiasingModel - INFO - Training: batch:95 accuracy:0.98828125
#
# 2021-04-13 18:06:45,364 - DebiasingModel - INFO - Training: batch:100 accuracy:0.9921875
#
# 2021-04-13 18:06:47,704 - DebiasingModel - INFO - Training: batch:105 accuracy:0.99609375
#
# 2021-04-13 18:06:50,023 - DebiasingModel - INFO - Training: batch:110 accuracy:0.99609375
#
# 2021-04-13 18:06:52,407 - DebiasingModel - INFO - Training: batch:115 accuracy:0.98046875
#
# 2021-04-13 18:06:54,737 - DebiasingModel - INFO - Training: batch:120 accuracy:0.99609375
#
# 2021-04-13 18:06:57,142 - DebiasingModel - INFO - Training: batch:125 accuracy:0.98828125
#
# 2021-04-13 18:06:59,624 - DebiasingModel - INFO - Training: batch:130 accuracy:0.98828125
#
# 2021-04-13 18:07:02,638 - DebiasingModel - INFO - Training: batch:135 accuracy:0.984375
#
# 2021-04-13 18:07:05,382 - DebiasingModel - INFO - Training: batch:140 accuracy:0.99609375
#
# 2021-04-13 18:07:07,936 - DebiasingModel - INFO - Training: batch:145 accuracy:0.99609375
#
# 2021-04-13 18:07:10,516 - DebiasingModel - INFO - Training: batch:150 accuracy:0.98046875
#
# 2021-04-13 18:07:13,119 - DebiasingModel - INFO - Training: batch:155 accuracy:0.9921875
#
# 2021-04-13 18:07:15,520 - DebiasingModel - INFO - Training: batch:160 accuracy:0.9921875
#
# 2021-04-13 18:07:17,914 - DebiasingModel - INFO - Training: batch:165 accuracy:0.984375
#
# 2021-04-13 18:07:20,277 - DebiasingModel - INFO - Training: batch:170 accuracy:0.98828125
#
# 2021-04-13 18:07:22,686 - DebiasingModel - INFO - Training: batch:175 accuracy:0.9921875
#
# 2021-04-13 18:07:25,083 - DebiasingModel - INFO - Training: batch:180 accuracy:0.99609375
#
# 2021-04-13 18:07:27,508 - DebiasingModel - INFO - Training: batch:185 accuracy:0.9921875
#
# 2021-04-13 18:07:29,993 - DebiasingModel - INFO - Training: batch:190 accuracy:1.0
#
# 2021-04-13 18:07:32,799 - DebiasingModel - INFO - Training: batch:195 accuracy:1.0
#
# 2021-04-13 18:07:35,504 - DebiasingModel - INFO - Training: batch:200 accuracy:0.9921875
#
# 2021-04-13 18:07:38,111 - DebiasingModel - INFO - Training: batch:205 accuracy:0.984375
#
# 2021-04-13 18:07:40,731 - DebiasingModel - INFO - Training: batch:210 accuracy:1.0
#
# 2021-04-13 18:07:43,832 - DebiasingModel - INFO - Training: batch:215 accuracy:0.98828125
#
# 2021-04-13 18:07:46,413 - DebiasingModel - INFO - Training: batch:220 accuracy:1.0
#
# 2021-04-13 18:07:48,925 - DebiasingModel - INFO - Training: batch:225 accuracy:1.0
#
# 2021-04-13 18:07:55,947 - DebiasingModel - INFO - Training: batch:230 accuracy:0.9921875
#
# 2021-04-13 18:07:58,351 - DebiasingModel - INFO - Training: batch:235 accuracy:0.99609375
#
# 2021-04-13 18:08:00,822 - DebiasingModel - INFO - Training: batch:240 accuracy:0.99609375
#
# 2021-04-13 18:08:03,329 - DebiasingModel - INFO - Training: batch:245 accuracy:0.99609375
#
# 2021-04-13 18:08:05,796 - DebiasingModel - INFO - Training: batch:250 accuracy:1.0
#
# 2021-04-13 18:08:08,280 - DebiasingModel - INFO - Training: batch:255 accuracy:0.99609375
#
# 2021-04-13 18:08:10,752 - DebiasingModel - INFO - Training: batch:260 accuracy:0.99609375
#
# 2021-04-13 18:08:13,369 - DebiasingModel - INFO - Training: batch:265 accuracy:0.99609375
#
# 2021-04-13 18:08:15,910 - DebiasingModel - INFO - Training: batch:270 accuracy:0.99609375
#
# 2021-04-13 18:08:18,376 - DebiasingModel - INFO - Training: batch:275 accuracy:0.9921875
#
# 2021-04-13 18:08:20,767 - DebiasingModel - INFO - Training: batch:280 accuracy:0.99609375
#
# 2021-04-13 18:08:23,226 - DebiasingModel - INFO - Training: batch:285 accuracy:1.0
#
# 2021-04-13 18:08:25,769 - DebiasingModel - INFO - Training: batch:290 accuracy:0.99609375
#
# 2021-04-13 18:08:28,250 - DebiasingModel - INFO - Training: batch:295 accuracy:0.99609375
#
# 2021-04-13 18:08:30,728 - DebiasingModel - INFO - Training: batch:300 accuracy:0.9921875
#
# 2021-04-13 18:08:33,248 - DebiasingModel - INFO - Training: batch:305 accuracy:1.0
#
# 2021-04-13 18:08:35,753 - DebiasingModel - INFO - Training: batch:310 accuracy:1.0
#
# 2021-04-13 18:08:38,248 - DebiasingModel - INFO - Training: batch:315 accuracy:1.0
#
# 2021-04-13 18:08:40,793 - DebiasingModel - INFO - Training: batch:320 accuracy:0.98828125
#
# 2021-04-13 18:08:43,292 - DebiasingModel - INFO - Training: batch:325 accuracy:0.99609375
#
# 2021-04-13 18:08:45,799 - DebiasingModel - INFO - Training: batch:330 accuracy:0.99609375
#
# 2021-04-13 18:08:48,292 - DebiasingModel - INFO - Training: batch:335 accuracy:0.9921875
#
# 2021-04-13 18:08:50,725 - DebiasingModel - INFO - Training: batch:340 accuracy:0.99609375
#
# 2021-04-13 18:08:59,559 - DebiasingModel - INFO - epoch 1/10::Training done
#
# 2021-04-13 18:08:59,560 - DebiasingModel - INFO - epoch 1/10 => train_loss=0.06, train_acc=0.99
#
# 2021-04-13 18:08:59,562 - DebiasingModel - INFO - Starting validation
#
# 2021-04-13 18:10:08,522 - DebiasingModel - INFO - Face percentage: 0.5
#
# 2021-04-13 18:10:09,553 - DebiasingModel - INFO - epoch 1/10::Validation done
#
# 2021-04-13 18:10:09,555 - DebiasingModel - INFO - epoch 1/10 => val_loss=0.03, val_acc=1.00
#
# 2021-04-13 18:10:09,990 - DebiasingModel - INFO -  💿 Stored model and results at results/train
#
# 2021-04-13 18:10:09,992 - DebiasingModel - INFO - Starting epoch: 2/10
#
# 2021-04-13 18:10:09,995 - DebiasingModel - INFO - Updating weight histogram using method: max
#
# 2021-04-13 18:10:29,441 - DebiasingModel - INFO -  💿 Saving a bias probability figure in results/train/bias_probs/epoch=1
#
# 2021-04-13 18:11:07,776 - DebiasingModel - INFO - Training: batch:0 accuracy:0.9921875
#
# 2021-04-13 18:11:18,677 - DebiasingModel - INFO - Training: batch:5 accuracy:0.9921875
#
# 2021-04-13 18:11:21,166 - DebiasingModel - INFO - Training: batch:10 accuracy:0.9921875
#
# 2021-04-13 18:11:23,532 - DebiasingModel - INFO - Training: batch:15 accuracy:0.9921875
#
# 2021-04-13 18:11:25,894 - DebiasingModel - INFO - Training: batch:20 accuracy:0.99609375
#
# 2021-04-13 18:11:28,256 - DebiasingModel - INFO - Training: batch:25 accuracy:0.98046875
#
# 2021-04-13 18:11:30,624 - DebiasingModel - INFO - Training: batch:30 accuracy:0.98828125
#
# 2021-04-13 18:11:32,992 - DebiasingModel - INFO - Training: batch:35 accuracy:0.9765625
#
# 2021-04-13 18:11:35,368 - DebiasingModel - INFO - Training: batch:40 accuracy:0.98828125
# 2021-04-13 18:11:37,757 - DebiasingModel - INFO - Training: batch:45 accuracy:0.99609375
#
# 2021-04-13 18:11:40,141 - DebiasingModel - INFO - Training: batch:50 accuracy:0.98828125
#
# 2021-04-13 18:11:42,533 - DebiasingModel - INFO - Training: batch:55 accuracy:0.9921875
#
# 2021-04-13 18:11:44,922 - DebiasingModel - INFO - Training: batch:60 accuracy:0.99609375
#
# 2021-04-13 18:11:47,306 - DebiasingModel - INFO - Training: batch:65 accuracy:0.99609375
#
# 2021-04-13 18:11:49,684 - DebiasingModel - INFO - Training: batch:70 accuracy:0.9921875
#
# 2021-04-13 18:11:52,060 - DebiasingModel - INFO - Training: batch:75 accuracy:0.9921875
#
# 2021-04-13 18:11:54,447 - DebiasingModel - INFO - Training: batch:80 accuracy:0.98828125
#
# 2021-04-13 18:11:56,820 - DebiasingModel - INFO - Training: batch:85 accuracy:0.99609375
#
# 2021-04-13 18:11:59,200 - DebiasingModel - INFO - Training: batch:90 accuracy:1.0
#
# 2021-04-13 18:12:01,579 - DebiasingModel - INFO - Training: batch:95 accuracy:1.0
#
# 2021-04-13 18:12:03,974 - DebiasingModel - INFO - Training: batch:100 accuracy:1.0
#
# 2021-04-13 18:12:06,364 - DebiasingModel - INFO - Training: batch:105 accuracy:0.99609375
#
# 2021-04-13 18:12:08,774 - DebiasingModel - INFO - Training: batch:110 accuracy:1.0
#
# 2021-04-13 18:12:11,151 - DebiasingModel - INFO - Training: batch:115 accuracy:0.99609375
#
# 2021-04-13 18:12:13,540 - DebiasingModel - INFO - Training: batch:120 accuracy:1.0
#
# 2021-04-13 18:12:15,938 - DebiasingModel - INFO - Training: batch:125 accuracy:1.0
#
# 2021-04-13 18:12:18,334 - DebiasingModel - INFO - Training: batch:130 accuracy:0.99609375
#
# 2021-04-13 18:12:20,727 - DebiasingModel - INFO - Training: batch:135 accuracy:1.0
#
# 2021-04-13 18:12:23,122 - DebiasingModel - INFO - Training: batch:140 accuracy:1.0
#
# 2021-04-13 18:12:25,517 - DebiasingModel - INFO - Training: batch:145 accuracy:0.99609375
#
# 2021-04-13 18:12:27,928 - DebiasingModel - INFO - Training: batch:150 accuracy:1.0
#
# 2021-04-13 18:12:30,475 - DebiasingModel - INFO - Training: batch:155 accuracy:0.98828125
#
# 2021-04-13 18:12:33,034 - DebiasingModel - INFO - Training: batch:160 accuracy:1.0
#
# 2021-04-13 18:12:35,586 - DebiasingModel - INFO - Training: batch:165 accuracy:1.0
#
# 2021-04-13 18:12:37,993 - DebiasingModel - INFO - Training: batch:170 accuracy:1.0
#
# 2021-04-13 18:12:40,472 - DebiasingModel - INFO - Training: batch:175 accuracy:0.99609375
#
# 2021-04-13 18:12:42,872 - DebiasingModel - INFO - Training: batch:180 accuracy:0.99609375
#
# 2021-04-13 18:12:45,300 - DebiasingModel - INFO - Training: batch:185 accuracy:1.0
#
# 2021-04-13 18:12:47,731 - DebiasingModel - INFO - Training: batch:190 accuracy:0.98046875
#
# 2021-04-13 18:12:50,308 - DebiasingModel - INFO - Training: batch:195 accuracy:0.99609375
#
# 2021-04-13 18:12:52,833 - DebiasingModel - INFO - Training: batch:200 accuracy:0.99609375
#
# 2021-04-13 18:12:55,290 - DebiasingModel - INFO - Training: batch:205 accuracy:1.0
#
# 2021-04-13 18:12:57,699 - DebiasingModel - INFO - Training: batch:210 accuracy:0.99609375
#
# 2021-04-13 18:13:00,184 - DebiasingModel - INFO - Training: batch:215 accuracy:1.0
#
# 2021-04-13 18:13:02,694 - DebiasingModel - INFO - Training: batch:220 accuracy:1.0
#
# 2021-04-13 18:13:05,255 - DebiasingModel - INFO - Training: batch:225 accuracy:0.9921875
#
# 2021-04-13 18:13:07,758 - DebiasingModel - INFO - Training: batch:230 accuracy:0.99609375
#
# 2021-04-13 18:13:10,244 - DebiasingModel - INFO - Training: batch:235 accuracy:0.9921875
#
# 2021-04-13 18:13:12,746 - DebiasingModel - INFO - Training: batch:240 accuracy:0.9921875
#
# 2021-04-13 18:13:15,233 - DebiasingModel - INFO - Training: batch:245 accuracy:1.0
#
# 2021-04-13 18:13:17,735 - DebiasingModel - INFO - Training: batch:250 accuracy:0.99609375
#
# 2021-04-13 18:13:20,295 - DebiasingModel - INFO - Training: batch:255 accuracy:0.99609375
#
# 2021-04-13 18:13:22,792 - DebiasingModel - INFO - Training: batch:260 accuracy:1.0
#
# 2021-04-13 18:13:25,311 - DebiasingModel - INFO - Training: batch:265 accuracy:1.0
#
# 2021-04-13 18:13:27,933 - DebiasingModel - INFO - Training: batch:270 accuracy:1.0
#
# 2021-04-13 18:13:30,583 - DebiasingModel - INFO - Training: batch:275 accuracy:1.0
#
# 2021-04-13 18:13:33,224 - DebiasingModel - INFO - Training: batch:280 accuracy:1.0
#
# 2021-04-13 18:13:35,835 - DebiasingModel - INFO - Training: batch:285 accuracy:0.984375
#
# 2021-04-13 18:13:38,460 - DebiasingModel - INFO - Training: batch:290 accuracy:1.0
#
# 2021-04-13 18:13:41,071 - DebiasingModel - INFO - Training: batch:295 accuracy:1.0
#
# 2021-04-13 18:13:43,711 - DebiasingModel - INFO - Training: batch:300 accuracy:0.99609375
#
# 2021-04-13 18:13:46,350 - DebiasingModel - INFO - Training: batch:305 accuracy:1.0
#
# 2021-04-13 18:13:48,960 - DebiasingModel - INFO - Training: batch:310 accuracy:1.0
#
# 2021-04-13 18:13:51,583 - DebiasingModel - INFO - Training: batch:315 accuracy:1.0
#
# 2021-04-13 18:13:54,212 - DebiasingModel - INFO - Training: batch:320 accuracy:1.0
#
# 2021-04-13 18:13:56,863 - DebiasingModel - INFO - Training: batch:325 accuracy:0.99609375
#
# 2021-04-13 18:13:59,502 - DebiasingModel - INFO - Training: batch:330 accuracy:1.0
#
# 2021-04-13 18:14:02,122 - DebiasingModel - INFO - Training: batch:335 accuracy:1.0
#
# 2021-04-13 18:14:04,709 - DebiasingModel - INFO - Training: batch:340 accuracy:1.0
#
# 2021-04-13 18:14:15,320 - DebiasingModel - INFO - epoch 2/10::Training done
#
# 2021-04-13 18:14:15,321 - DebiasingModel - INFO - epoch 2/10 => train_loss=0.03, train_acc=1.00
#
# 2021-04-13 18:14:15,323 - DebiasingModel - INFO - Starting validation
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-a659739fe524> in <module>
# ----> 1 trainer.train(10)
#
# ~\debiasing\FACT\code\trainer.py in train(self, epochs)
#     138             # Validation
#     139             logger.info("Starting validation")
# --> 140             val_loss, val_acc = self._eval_epoch(epoch)
#     141             epoch_val_t = datetime.now() - epoch_start_t
#     142             logger.info(f"epoch {epoch+1}/{epochs}::Validation done")
#
# ~\debiasing\FACT\code\trainer.py in _eval_epoch(self, epoch)
#     249
#     250         with torch.no_grad():
# --> 251             for i, (face_batch, nonface_batch) in enumerate(zip(face_loader, nonface_loader)):
#     252                 images, labels, idxs = utils.concat_batches(face_batch, nonface_batch)
#     253
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     276             return _SingleProcessDataLoaderIter(self)
#     277         else:
# --> 278             return _MultiProcessingDataLoaderIter(self)
#     279
#     280     @property
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     680             #     before it starts, and __del__ tries to join but will get:
#     681             #     AssertionError: can only join a started process.
# --> 682             w.start()
#     683             self.index_queues.append(index_queue)
#     684             self.workers.append(w)
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      87             try:
#      88                 reduction.dump(prep_data, to_child)
# ---> 89                 reduction.dump(process_obj, to_child)
#      90             finally:
#      91                 set_spawning_popen(None)
#
# ~\anaconda3\envs\Msc_AI_FACT_Windows\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# OSError: [Errno 22] Invalid argument

# %% [markdown]
# ### Analyse the recreated images by the VAE in a 10 by 10 matrix

# %%
trainer.sample(10)

# %% [markdown]
# ### Observing the recreation of actual images by the VAE

# %% [markdown]
# We can recreate actual images by the VAE.

# %%
trainer.reconstruction_samples()
# Out:
# C:\Users\driti\anaconda3\envs\Msc_AI_FACT_Windows\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ### Analysing which images are best predicted and worst predicted

# %% [markdown]
# We can analyse the best and worst predicted images.

# %%
trainer.best_and_worst()
# Out:
# 2021-04-13 18:17:33,580 - DebiasingModel - INFO - Face percentage: 0.5

# %% [markdown]
# ## Evaluate a model

# %% [markdown]
# ### Creating an evaluation object
# We load in the model from the folder **train**. Set `path_to_model` to any folder in `results/` with a model.pt to load in that corresponding model.

# %%
eval_config = Config(path_to_model='train')
evaluator = make_evaluator(eval_config)
# Out:
# 2021-04-13 18:18:17,008 - DebiasingModel - INFO - Loaded model from train!

# %% [markdown]
# ### Perform the actual evaluation on the defined subset

# %% [markdown]
# We evaluate the model performance, and save the results in the same area where the model was extracted from.

# %%
evaluator.eval_on_setups("test.csv")
# Out:
# 2021-04-13 18:18:34,434 - DebiasingModel - INFO - Running setup for dark male
#
# 2021-04-13 18:18:34,435 - DebiasingModel - INFO - Evaluating on PPB
#
# 2021-04-13 18:20:01,100 - DebiasingModel - INFO - Amount of labels:318, Correct labels:307
#
# 2021-04-13 18:20:01,115 - DebiasingModel - INFO - Recall for dark male is 96.541
#
# 2021-04-13 18:20:01,116 - DebiasingModel - INFO - Running setup for dark female
#
# 2021-04-13 18:20:01,121 - DebiasingModel - INFO - Evaluating on PPB
#
# 2021-04-13 18:21:13,010 - DebiasingModel - INFO - Amount of labels:271, Correct labels:270
#
# 2021-04-13 18:21:13,019 - DebiasingModel - INFO - Recall for dark female is 99.631
#
# 2021-04-13 18:21:13,019 - DebiasingModel - INFO - Running setup for light male
#
# 2021-04-13 18:21:13,020 - DebiasingModel - INFO - Evaluating on PPB
#
# 2021-04-13 18:22:57,882 - DebiasingModel - INFO - Amount of labels:386, Correct labels:372
#
# 2021-04-13 18:22:57,890 - DebiasingModel - INFO - Recall for light male is 96.373
#
# 2021-04-13 18:22:57,891 - DebiasingModel - INFO - Running setup for light female
#
# 2021-04-13 18:22:57,892 - DebiasingModel - INFO - Evaluating on PPB
#
# 2021-04-13 18:24:18,100 - DebiasingModel - INFO - Amount of labels:295, Correct labels:290
#
# 2021-04-13 18:24:18,117 - DebiasingModel - INFO - Recall for light female is 98.305
#
# 2021-04-13 18:24:18,121 - DebiasingModel - INFO - Evaluating on negative samples
#
# 2021-04-13 18:24:18,122 - DebiasingModel - INFO - Evaluating on Imagenet H5
#
# 2021-04-13 18:24:39,450 - DebiasingModel - INFO - Evaluation on a sub-set of 1270 nr images
#
# 2021-04-13 18:30:28,757 - DebiasingModel - INFO - Amount of labels:1270, Correct labels:428
#
# 2021-04-13 18:30:28,945 - DebiasingModel - INFO - Recall => all: 97.559
#
# 2021-04-13 18:30:28,946 - DebiasingModel - INFO - Recall => dark male: 96.541
#
# 2021-04-13 18:30:28,947 - DebiasingModel - INFO - Recall => dark female: 99.631
#
# 2021-04-13 18:30:28,947 - DebiasingModel - INFO - Recall => white male: 96.373
#
# 2021-04-13 18:30:28,948 - DebiasingModel - INFO - Recall => white female: 98.305
#
# 2021-04-13 18:30:28,949 - DebiasingModel - INFO - Variance => 2.400
#
# 2021-04-13 18:30:28,951 - DebiasingModel - INFO - Precision => 49.382
#
# 2021-04-13 18:30:28,955 - DebiasingModel - INFO - Accuracy => 81.929
#
# 2021-04-13 18:30:28,964 - DebiasingModel - INFO - ✅ Finished evaluation!

# %% [markdown]
# ## Our own final results

# %% [markdown]
# Included in this notebook is an analysis of our own results for max5, based on the training of 5 different models.

# %%
df_final_results = pd.read_csv("paper_results/results.csv")

# %% [markdown]
# ### Analysis of the Recall of the non-debiased and max-based debiased

# %%
# Recall setup
colors = ["#fffecb", "#a1dab4", "#41b6c4", "#2c7fb8", "#253594"]
training_type = ["no debias", r"$\alpha$ = 0.1", r"$\alpha$ = 0.05", r"$\alpha$ = 0.01", r"$\alpha$ = 0.001"]
setups = ["dark male", "dark female", "light male", "light female", "recall"]
name_list = ["train1_", "train2_", "train3", "train4", "train5"]

utils.make_bar_plot(df_final_results, name_list, setups, training_type=training_type, colors=colors, y_lim=(80, 105), y_label="Recall")

# %% [markdown]
# ### Precision, Recall and Accuracy of the non-debiased and max-based debiased

# %%
# Setup to extract precision recall and accuracy
colors = ["#fffecb", "#a1dab4", "#41b6c4", "#2c7fb8", "#253594"]
training_type = ["no debias", r"$\alpha$ = 0.1", r"$\alpha$ = 0.05", r"$\alpha$ = 0.01", r"$\alpha$ = 0.001"]
name_list = ["train1_", "train2", "train3", "train4", "train5"]
setups = ["precision", "recall", "accuracy"]

utils.make_bar_plot(df_final_results, name_list, setups, training_type=training_type, colors=colors, y_lim=(60,100))

# %% [markdown]
# ### Variance of non-debiased, max and gaussian models

# %%
# Define the colors
col1 = '#FFEC00'
col2 = '#FF5300'
col3 = '#00AB6F'
col4 = '#580EAD'
colors = [col1, col2, col2, col2, col2,
                col3, col3, col3, col3,
                col4, col4, col4, col4]

# Define the setup names
name_list = [f"train{i}" for i in [1,2,3,4,5,12,13,14,15,17,18,19,20]]
name_list[0] = "train1_"

t_type = [" ", "no debias", "max\n"+r"$\alpha$ = 0.1", "max\n"+r"$\alpha$ = 0.05", 
                      "max\n"+r"$\alpha$ = 0.01", "max\n"+r"$\alpha$ = 0.001",
                      "max 5\n"+r"$\alpha$ = 0.1", "max 5\n"+r"$\alpha$ = 0.05", 
                      "max 5\n"+r"$\alpha$ = 0.01", "max 5\n"+r"$\alpha$ = 0.001",
                      "gaussian\n"+r"$\alpha$ = 0.1", "gaussian\n"+r"$\alpha$ = 0.05", 
                      "gaussian\n"+r"$\alpha$ = 0.01", "gaussian\n"+r"$\alpha$ = 0.001"]
y_lim = [0, 100]

utils.make_box_plot(df_final_results, name_list, training_type=t_type, colors=colors, y_lim=y_lim)
